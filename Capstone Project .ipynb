# %% [markdown]
# This notebook will mainly be used for the capstone project

# %%
import pandas as pd
import numpy as np
print ()
# Out:
#   File "<ipython-input-6-c3c00cf38b4a>", line 3
#     print "Hello Capstone Project Course!"
#                                          ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello Capstone Project Course!")?
